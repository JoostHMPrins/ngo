# %%
from nutils import function, mesh, solver
from nutils.expression_v2 import Namespace
import numpy
from matplotlib import pyplot as plt

topo, geom = mesh.rectilinear([numpy.linspace(0, 1, 5)])

ns = Namespace()
ns.x = geom
ns.define_for('x', gradient='∇', normal='n', jacobians=('dV', 'dS'))
ns.basis = topo.basis('spline', degree=1)
ns.u = function.dotarg('lhs', ns.basis)

sqr = topo.boundary['left'].integral('u^2 dS' @ ns, degree=2)
cons = solver.optimize('lhs', sqr, droptol=1e-15)
# optimize > constrained 1/5 dofs
# optimize > optimum value 0.00e+00

res = topo.integral('∇_i(basis_n) ∇_i(u) dV' @ ns, degree=0)
res -= topo.boundary['right'].integral('basis_n dS' @ ns, degree=0)
lhs = solver.solve_linear('lhs', residual=res, constrain=cons)
# solve > solving 4 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 9e-16±1e-15

bezier = topo.sample('bezier', 32)
nanjoin = lambda array, tri: numpy.insert(array.take(tri.flat, 0).astype(float),
    slice(tri.shape[1], tri.size, tri.shape[1]), numpy.nan, axis=0)
sampled_x = nanjoin(bezier.eval('x_0' @ ns), bezier.tri)
def plot_line(func, **arguments):
    plt.plot(sampled_x, nanjoin(bezier.eval(func, **arguments), bezier.tri))
    plt.xlabel('x_0')
    plt.xticks(numpy.linspace(0, 1, 5))

plot_line(ns.u, lhs=lhs)
# Out:
# optimize > constrained 1/5 dofs
# optimize > optimum value 0.00e+00
# solve > solving 4 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 0e+00

# %%
mesh.rectilinear([[0, 0.25, 0.5, 0.75, 1.0]])
# Out:
# (StructuredTopology<4>, Array<1>)

# %%
topo, geom = mesh.rectilinear([numpy.linspace(0, 1, 5)])

# %%
mesh.rectilinear([numpy.linspace(0, 1, 5), numpy.linspace(0, 1, 9)])
# Out:
# (StructuredTopology<4x8>, Array<2>)

# %%
topo.boundary['left']
# Out:
# StructuredTopology<>

# %%
mesh.rectilinear([numpy.linspace(0, 1, 5), numpy.linspace(0, 1, 9)], periodic=[1])
# Out:
# (StructuredTopology<4x8p>, Array<2>)

# %%
basis = topo.basis('spline', degree=1)
plot_line(basis)

# %%
basis = topo.basis('spline', degree=2)
plot_line(basis)

# %%
plot_line(topo.basis('spline', degree=2, continuity=0))

# %%
plot_line(topo.basis('std', degree=2))

# %%
plot_line(topo.basis('discont', degree=2))

# %%
geom
# Out:
# Array<1>

# %%
geom.shape
# Out:
# (1,)

# %%
basis
# Out:
# Array<5>

# %%
basis.shape
# Out:
# (5,)

# %%
geom.ndim
# Out:
# 1

# %%
geom.dtype
# Out:
# float

# %%
geom[0]
# Out:
# Array<>

# %%
plot_line(basis[:2])

# %%
plot_line(geom[0]*(1-geom[0])/2)

# %%
plot_line(function.sin(2*geom[0]*numpy.pi))

# %%
plot_line(function.dot(basis, [1,2,0,5,4]))

# %%
ns.u = function.dotarg('lhs', ns.basis)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 ns.u = function.dotarg('lhs', ns.basis)
#
# AttributeError: 'Namespace' object has no attribute 'basis'

# %%
ns = Namespace()

# %%
ns.x = geom

# %%
ns.define_for('x', gradient='∇', normal='n', jacobians=('dV', 'dS'))

# %%
ns.basis = topo.basis('spline', degree=1)

# %%
ns.u = function.dotarg('lhs', ns.basis)

# %%
ns.a = 1
ns.b = 2
ns.c = numpy.array([1,2])
ns.A = numpy.array([[1,2],[3,4]])

# %%
ns.e = '2 a / 3 b'
ns.e = (2*ns.a) / (3*ns.b) # equivalent w/o expression

# %%
localvar = 1
ns.f = '2 localvar'
# Out:
# ---------------------------------------------------------------------------
# ExpressionSyntaxError                     Traceback (most recent call last)
# Cell In[56], line 2
#       1 localvar = 1
# ----> 2 ns.f = '2 localvar'
#
# File ~/.local/lib/python3.10/site-packages/nutils/expression_v2.py:629, in Namespace.__setattr__(self, attr, value)
#     627     raise AttributeError('All indices must be unique.')
#     628 ops = _FunctionArrayOps(self)
# --> 629 array, shape, expression_indices, summed = _Parser(ops).parse_expression(_Substring(value))
#     630 assert numpy.shape(array) == shape
#     631 if expression_indices != indices:
#
# File ~/.local/lib/python3.10/site-packages/nutils/expression_v2.py:287, in _Parser.parse_expression(self, s)
#     284     negate = True
#     285 # Parse terms separated by ` + ` or ` - `. If the expression is empty,
#     286 # `split` yields once and `self.parse_fraction` will raise an exception.
# --> 287 unaligned = tuple((imatcher == 1, s_term, self.parse_fraction(s_term)) for imatcher, s_term in s_tail.isplit(_match(' + '), _match(' - '), first=1 if negate else 0))
#     288 # Check that all terms have the same indices and transpose all but the
#     289 # first array such that all terms have the same order of indices.
#     290 negate, s_first, (term, shape, indices, summed_indices) = unaligned[0]
#
# File ~/.local/lib/python3.10/site-packages/nutils/expression_v2.py:287, in <genexpr>(.0)
#     284     negate = True
#     285 # Parse terms separated by ` + ` or ` - `. If the expression is empty,
#     286 # `split` yields once and `self.parse_fraction` will raise an exception.
# --> 287 unaligned = tuple((imatcher == 1, s_term, self.parse_fraction(s_term)) for imatcher, s_term in s_tail.isplit(_match(' + '), _match(' - '), first=1 if negate else 0))
#     288 # Check that all terms have the same indices and transpose all but the
#     289 # first array such that all terms have the same order of indices.
#     290 negate, s_first, (term, shape, indices, summed_indices) = unaligned[0]
#
# File ~/.local/lib/python3.10/site-packages/nutils/expression_v2.py:321, in _Parser.parse_fraction(self, s)
#     319     raise ExpressionSyntaxError('Repeated fractions are not allowed. Use parentheses if necessary.', s.trim())
#     320 # Parse the numerator.
# --> 321 numerator, shape, indices, numerator_summed_indices = self.parse_term(s_parts[0])
#     322 if len(s_parts) == 1:
#     323     # There is no denominator. Return the numerator as is.
#     324     return numerator, shape, indices, numerator_summed_indices
#
# File ~/.local/lib/python3.10/site-packages/nutils/expression_v2.py:345, in _Parser.parse_term(self, s)
#     342     return self.parse_power(s, allow_number=True)
#     343 # Split the substring at spaces and parse the items using `parse_power`.
#     344 # The first items is allowed to be a number, the remainder is not.
# --> 345 parts = tuple(self.parse_power(s_part, allow_number=i == 0) for i, s_part in enumerate(s_trimmed.split(_match_spaces)))
#     346 if len(parts) == 1:
#     347     # There is only one item in the term. Return this item as is.
#     348     return parts[0]
#
# File ~/.local/lib/python3.10/site-packages/nutils/expression_v2.py:345, in <genexpr>(.0)
#     342     return self.parse_power(s, allow_number=True)
#     343 # Split the substring at spaces and parse the items using `parse_power`.
#     344 # The first items is allowed to be a number, the remainder is not.
# --> 345 parts = tuple(self.parse_power(s_part, allow_number=i == 0) for i, s_part in enumerate(s_trimmed.split(_match_spaces)))
#     346 if len(parts) == 1:
#     347     # There is only one item in the term. Return this item as is.
#     348     return parts[0]
#
# File ~/.local/lib/python3.10/site-packages/nutils/expression_v2.py:364, in _Parser.parse_power(self, s, allow_number)
#     362         raise ExpressionSyntaxError('Unexpected whitespace after `^`.', s_parts[1][:1])
#     363 # Parse the base.
# --> 364 base, shape, indices, base_summed_indices = self.parse_item(s_parts[0], allow_number=allow_number)
#     365 if len(s_parts) == 1:
#     366     # There's no exponent. Return the base as is.
#     367     return base, shape, indices, base_summed_indices
#
# File ~/.local/lib/python3.10/site-packages/nutils/expression_v2.py:431, in _Parser.parse_item(self, s, allow_number)
#     429 result = self.array.get_variable(str(s_name), len(s_generated_indices))
#     430 if result is None:
# --> 431     raise ExpressionSyntaxError('No such variable: `{}`.'.format(s_name), s_name)
#     432 elif isinstance(result, _InvalidDimension):
#     433     raise ExpressionSyntaxError('Expected {} for variable `{}` but got {}.'.format(_sp(result.actual_ndim, 'index', 'indices'), s_name, len(s_generated_indices)), s_trimmed)
#
# ExpressionSyntaxError: No such variable: `localvar`.
# 2 localvar
#   ^^^^^^^^

# %%
ns.f_i = '2 c_i'
ns.f = 2*ns.c # equivalent w/o expression

# %%
ns.g_ijk = 'c_i A_jk'
ns.g_kji = 'c_k A_ji'
ns.g = ns.c[:,numpy.newaxis,numpy.newaxis]*ns.A[numpy.newaxis,:,:] # equivalent w/o expression

# %%
'2 a / 3 b' @ ns
# Array<>
(2*ns.a) / (3*ns.b) # equivalent w/o `... @ ns`
# Array<>
# Out:
# Array<>

# %%
'2 c_i' @ ns
# Array<2>
2*ns.c # equivalent w/o `... @ ns`
# Array<2>
# Out:
# Array<2>

# %%
'c_i A_jk' @ ns
# Array<2,2,2>
ns.c[:,numpy.newaxis,numpy.newaxis]*ns.A[numpy.newaxis,:,:] # equivalent w/o `... @ ns`
# Array<2,2,2>
# Out:
# Array<2,2,2>

# %%
I = topo.integral('1 dV' @ ns, degree=0)
I
# Array<>
# Out:
# Array<>

# %%
I.eval()
# 1.0±1e-15
# Out:
# 1.0

# %%
topo.integral('(1 + 1) dV' @ ns, degree=0).eval()
# 2.0±1e-15
topo.integral('1 + 1 dV' @ ns, degree=0).eval()
# 5.0±1e-15
# Out:
# 5.0

# %%
J = topo.integral('x_0 dV' @ ns, degree=1)
(I+J).eval()
# 1.5±1e-15
# Out:
# 1.5

# %%
topo.boundary.integral('x_0 dS' @ ns, degree=1).eval()
# 1.0±1e-15
# Out:
# 1.0

# %%
topo.boundary['right'].integral('x_0 dS' @ ns, degree=1).eval()
# 1.0±1e-15
# Out:
# 1.0

# %%
topo.integral('basis_i dV' @ ns, degree=1).eval()
# Out:
# array([0.125, 0.25 , 0.25 , 0.25 , 0.125])

# %%
M = topo.integral('∇_i(basis_m) ∇_i(basis_n) dV' @ ns, degree=1).eval()
M.export('dense')
# Out:
# array([[ 4., -4.,  0.,  0.,  0.],
#        [-4.,  8., -4.,  0.,  0.],
#        [ 0., -4.,  8., -4.,  0.],
#        [ 0.,  0., -4.,  8., -4.],
#        [ 0.,  0.,  0., -4.,  4.]])

# %%
M.export('csr') # (data, column indices, row pointers) # doctest: +NORMALIZE_WHITESPACE
# Out:
# (array([ 4., -4., -4.,  8., -4., -4.,  8., -4., -4.,  8., -4., -4.,  4.]),
#  array([0, 1, 0, 1, 2, 1, 2, 3, 2, 3, 4, 3, 4], dtype=int32),
#  array([ 0,  2,  5,  8, 11, 13], dtype=int32))

# %%
M.export('coo')
# Out:
# (array([ 4., -4., -4.,  8., -4., -4.,  8., -4., -4.,  8., -4., -4.,  4.]),
#  (array([0, 0, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4]),
#   array([0, 1, 0, 1, 2, 1, 2, 3, 2, 3, 4, 3, 4], dtype=int32)))

# %%
A = topo.integral('basis_m basis_n dV' @ ns, degree=2).eval()
f = topo.integral('basis_n x_0 dV' @ ns, degree=2).eval()
A.solve(f)
# Out:
# solve > solving 5 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 3e-17
# array([5.77936353e-17, 2.50000000e-01, 5.00000000e-01, 7.50000000e-01,
#        1.00000000e+00])

# %%
res = topo.integral('basis_n (u - x_0) dV' @ ns, degree=2)

# %%
A = res.derivative('lhs').eval()
f = -res.eval(lhs=numpy.zeros(5))
A.solve(f)
# Out:
# solve > solving 5 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 3e-17
# array([5.77936353e-17, 2.50000000e-01, 5.00000000e-01, 7.50000000e-01,
#        1.00000000e+00])

# %%
solver.solve_linear('lhs', res)
# Out:
# solve > solving 5 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 3e-17
# array([5.77936353e-17, 2.50000000e-01, 5.00000000e-01, 7.50000000e-01,
#        1.00000000e+00])

# %%
sqr = topo.integral('(u - x_0)^2 dV' @ ns, degree=2)
solver.solve_linear('lhs', sqr.derivative('lhs'))
# Out:
# solve > solving 5 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 6e-17
# array([5.77936353e-17, 2.50000000e-01, 5.00000000e-01, 7.50000000e-01,
#        1.00000000e+00])

# %%
solver.optimize('lhs', sqr)
# Out:
# optimize > solve > solving 5 dof system to machine precision using arnoldi solver
# optimize > solve > solver returned with residual 4e-17
# optimize > optimum value 5.55e-17
# array([3.39934989e-17, 2.50000000e-01, 5.00000000e-01, 7.50000000e-01,
#        1.00000000e+00])

# %%
sqr = topo.boundary['left'].integral('(u - 0)^2 dS' @ ns, degree=2)

# %%
cons = solver.optimize('lhs', sqr, droptol=1e-15)
# Out:
# optimize > constrained 1/5 dofs
# optimize > optimum value 0.00e+00

# %%
cons
# Out:
# array([ 0., nan, nan, nan, nan])

# %%
res = topo.integral('∇_i(basis_n) ∇_i(u) dV' @ ns, degree=0) - topo.boundary['right'].integral('basis_n dS' @ ns, degree=0)

# %%
lhs = solver.solve_linear('lhs', res, constrain=cons)
# Out:
# solve > solving 4 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 0e+00

# %%
lhs
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
bezier = topo.sample('bezier', 2)

# %%
x = bezier.eval('x_0' @ ns)
x
# Out:
# array([0.  , 0.25, 0.25, 0.5 , 0.5 , 0.75, 0.75, 1.  ])

# %%
x.take(bezier.tri, 0)
# Out:
# array([[0.  , 0.25],
#        [0.25, 0.5 ],
#        [0.5 , 0.75],
#        [0.75, 1.  ]])

# %%
x.take(bezier.tri.T, 0)
# Out:
# array([[0.  , 0.25, 0.5 , 0.75],
#        [0.25, 0.5 , 0.75, 1.  ]])

# %%
u = bezier.eval('u' @ ns, lhs=lhs)
u
# Out:
# array([0.  , 0.25, 0.25, 0.5 , 0.5 , 0.75, 0.75, 1.  ])

# %%
u.take(bezier.tri, 0)
# Out:
# array([[0.  , 0.25],
#        [0.25, 0.5 ],
#        [0.5 , 0.75],
#        [0.75, 1.  ]])

# %%
u.take(bezier.tri.T, 0)
# Out:
# array([[0.  , 0.25, 0.5 , 0.75],
#        [0.25, 0.5 , 0.75, 1.  ]])

# %%
plt.plot(x.take(bezier.tri.T, 0), u.take(bezier.tri.T, 0))
# Out:
# [<matplotlib.lines.Line2D at 0x7f031d742c20>,
#  <matplotlib.lines.Line2D at 0x7f031d742c80>,
#  <matplotlib.lines.Line2D at 0x7f031d742cb0>,
#  <matplotlib.lines.Line2D at 0x7f031d742da0>]

# %%
nanjoin = lambda array, tri: numpy.insert(array.take(tri.flat, 0).astype(float),
    slice(tri.shape[1], tri.size, tri.shape[1]), numpy.nan, axis=0)
nanjoin(x, bezier.tri)
# Out:
# array([0.  , 0.25,  nan, 0.25, 0.5 ,  nan, 0.5 , 0.75,  nan, 0.75, 1.  ])

# %%
plt.plot(nanjoin(x, bezier.tri), nanjoin(u, bezier.tri))
