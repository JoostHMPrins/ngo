# %%
import sys
sys.path.insert(0,'../ml')
from quadrature import GaussLegendreQuadrature

import matplotlib.pyplot as plt

# %%
Q = (99,99)
n_elements = (3,3)
quad = GaussLegendreQuadrature(Q, n_elements)

# %%
plt.scatter(quad.xi[:,0],quad.xi[:,1],c=quad.w)
