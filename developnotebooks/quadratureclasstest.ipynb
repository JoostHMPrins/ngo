# %%
import numpy as np

import sys
sys.path.insert(0, '../ml')
from quadrature import *
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
Q = 10
quadrature = UniformQuadrature2D(Q=Q)
# quadrature = GaussLegendreQuadrature2D(Q=Q, n_elements=Q)
# quadrature.w_Omega[np.sqrt((quadrature.xi_Omega[:,0]-0.5)**2+(quadrature.xi_Omega[:,1]-0.5)**2) - 0.25 < 1/10] = 10
# quadrature.w_Omega[np.sqrt((quadrature.xi_Omega[:,0]-0.5)**2+(quadrature.xi_Omega[:,1]-0.5)**2) - 0.4 < 0.5*1/99] = 0
# quadrature.w_Omega[np.abs(np.sqrt((quadrature.xi_Omega[:,0]-0.5)**2+(quadrature.xi_Omega[:,1]-0.5)**2) - 0.4) < 0.5*1/99] = 0

# %%
# Q = 100
# n_elements = 5
# quadrature = GaussLegendreQuadrature2D(Q=Q, n_elements=n_elements)

# %%
quadrature.plot_quadraturegrid()
