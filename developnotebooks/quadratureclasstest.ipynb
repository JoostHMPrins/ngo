# %%
import numpy as np

import sys
sys.path.insert(0, '../ml')
from quadrature import *
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Q = 10
quadrature = UniformQuadrature2D(Q=Q)

# %%
# Q = 100
# n_elements = 5
# quadrature = GaussLegendreQuadrature2D(Q=Q, n_elements=n_elements)

# %%
quadrature.plot_quadraturegrid()

# %%
plt.scatter(quadrature.xi_Gamma_r[:,0], quadrature.xi_Gamma_r[:,1], c=quadrature.w_Gamma_r, s=10)
plt.axis('square')
plt.colorbar()
plt.xlim(0,1)
plt.ylim(0,1)
print(1/quadrature.w_Gamma_r)
# Out:
# [10. 10. 10. 10. 10. 10. 10. 10. 10. 10.]
