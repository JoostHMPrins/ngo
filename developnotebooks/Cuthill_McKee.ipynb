# %%
F = np.load("F.npy")

# %%
import numpy as np
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import reverse_cuthill_mckee
import matplotlib.pyplot as plt

# Generate a 100x100 matrix with multiple diagonal bands
A = F[0]

# Convert to sparse matrix format
A_sparse = csr_matrix(A)

# Apply Reverse Cuthill-McKee algorithm
perm = reverse_cuthill_mckee(A_sparse)

# Reorder the matrix according to the permutation
A_single_band = A_sparse[perm, :][:, perm].toarray()

# Visualize the original and reordered matrix
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.imshow(A)
ax1.set_title("Original Matrix with Multiple Bands")
ax2.imshow(A_single_band)
ax2.set_title("Single Diagonal Band Matrix")
plt.show()

# %%
plt.imshow(A_single_band)
plt.colorbar()
